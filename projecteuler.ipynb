# %% [markdown]
# ### Problem 1 from Project Euler

# %% [markdown]
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6, and 9.  The sum of these multiples is 23.
#
# Find the sum of all the multiples of 3 or 5 below 1000.

# %%
def sum_of_mults(N):
    nums = []
    for i in range(N):
        if i%5==0:
            nums.append(i)
            continue
        if i%3==0:
            nums.append(i)
    return sum(nums)

# %% [markdown]
# #### Test with the example

# %%
sum_of_mults(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-cca5138b6942> in <module>()
# ----> 1 sum_of_mults(10)
#
# <ipython-input-10-702601a6b4db> in sum_of_mults(N)
#       2     nums = []
#       3     for i in enumerate(range(N)):
# ----> 4         if i%5==0:
#       5             nums.append(i)
#       6             continue
#
# TypeError: unsupported operand type(s) for %: 'tuple' and 'int'

# %% [markdown]
# #### Get Answer

# %%
sum_of_mults(1000)
# Out:
# 233168
